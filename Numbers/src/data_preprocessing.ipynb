# %%
import os
import mediapipe as mp
import cv2
import pickle
import matplotlib.pyplot as plt
from log import get_logger  # Import logger from our log.py
import logging
import numpy as np  # Added for sharpening kernel/array operations
import glob  # Added for efficient image counting

# %%
# Logger setup
logger = get_logger(__name__)
logging.getLogger('matplotlib.font_manager').disabled = True

# %%
# Global constants
DATA_DIR = '/Users/ashishsingh/Desktop/SIGN01/data/numbers'
GRAPH_DIR = '/Users/ashishsingh/Desktop/SIGN01/graphs'
PROCESSED_DATA_DIR = '/Users/ashishsingh/Desktop/SIGN01/data/processed_data/numbers'

# Ensure graph directory exists
os.makedirs(GRAPH_DIR, exist_ok=True)

# %%
def init_mp_hands(static_mode=True, min_confidence=0.7, min_tracking_confidence=0.7):
    """
    Initializes and returns a MediaPipe Hands object.
    """
    logger.info("Initializing MediaPipe Hands...")
    mp_hands = mp.solutions.hands
    return mp_hands.Hands(
        static_image_mode=static_mode,
        min_detection_confidence=min_confidence,
        min_tracking_confidence=min_tracking_confidence
    )

# %%
def sharpen_image(image):
    """
    Applies unsharp masking to sharpen the image for better handling of blur.
    """
    blurred = cv2.GaussianBlur(image, (0, 0), sigmaX=3)
    sharpened = cv2.addWeighted(image, 1.5, blurred, -0.5, 0)
    return sharpened

# %%
def count_total_images(data_dir):
    """
    Counts the total number of image files in the dataset directory and subdirectories.
    """
    image_paths = glob.glob(os.path.join(data_dir, '**/*.jpg'), recursive=True) + \
                  glob.glob(os.path.join(data_dir, '**/*.png'), recursive=True)  # Add other extensions if needed
    total = len(image_paths)
    logger.info(f"Found {total} images to process in {data_dir}.")
    return total

# %%
def process_images(data_dir, hands):
    """
    Processes images from the dataset directory using MediaPipe Hands
    and returns data and labels. Includes image sharpening for blur correction.
    """
    logger.info(f"Processing images from: {data_dir}")
    data = []
    labels = []

    # Count total images upfront
    total_images = count_total_images(data_dir)

    processed_count = 0  # To track images with successful detections
    skipped_count = 0    # Optional: Track skips for invalid loads or no detection

    for dir_ in os.listdir(data_dir):
        dir_path = os.path.join(data_dir, dir_)
        if dir_.startswith('.') or not os.path.isdir(dir_path):  # Skip hidden files and non-dirs
            logger.debug(f"Skipping: {dir_}")
            continue
        for img_filename in os.listdir(dir_path):
            img_path = os.path.join(dir_path, img_filename)
            if not os.path.isfile(img_path):  # Skip non-files
                continue

            img = cv2.imread(img_path)
            if img is None:
                logger.warning(f"Failed to load image: {img_path}")
                skipped_count += 1
                continue

            # Preprocess: Sharpen to handle potential blur
            sharpened_img = sharpen_image(img)

            # Convert to RGB for MediaPipe
            img_rgb = cv2.cvtColor(sharpened_img, cv2.COLOR_BGR2RGB)

            results = hands.process(img_rgb)
            if results.multi_hand_landmarks:
                data_aux = [0] * 84  # 2 hands × (21 landmarks × 2 coords)
                for i, hand_landmarks in enumerate(results.multi_hand_landmarks[:2]):
                    x_ = [landmark.x for landmark in hand_landmarks.landmark]
                    y_ = [landmark.y for landmark in hand_landmarks.landmark]

                    hand_data = []
                    for landmark in hand_landmarks.landmark:
                        hand_data.append(landmark.x - min(x_))
                        hand_data.append(landmark.y - min(y_))

                    start_idx = i * 42
                    data_aux[start_idx:start_idx + 42] = hand_data

                data.append(data_aux)
                labels.append(dir_)
                processed_count += 1
            else:
                logger.debug(f"No hands detected in {img_path}")
                skipped_count += 1

    logger.info(f"Processing complete: {total_images} images total, MediaPipe detected hands in {processed_count} images (skipped {skipped_count}).")
    return data, labels

# %%
def save_data_pickle(data, labels, save_dir=PROCESSED_DATA_DIR):
    """
    Saves processed data and labels to a pickle file in processed_data folder.
    """
    os.makedirs(save_dir, exist_ok=True)  # Ensures directory exists
    save_path = os.path.join(save_dir, "data.pickle")
    with open(save_path, "wb") as f:
        pickle.dump({"data": data, "labels": labels}, f)
    logger.info(f"Processed data saved to {save_path}")

# %%
def visualize_data(labels, save_dir=GRAPH_DIR):
    """
    Creates a bar chart showing the number of samples per label.
    """
    logger.info("Generating dataset distribution visualization...")
    label_counts = {}
    for label in labels:
        label_counts[label] = label_counts.get(label, 0) + 1

    save_path = os.path.join(save_dir, 'data_visualization.png')

    plt.figure(figsize=(10, 6))
    plt.bar(label_counts.keys(), label_counts.values(), color='skyblue')
    plt.xlabel('Labels')
    plt.ylabel('Number of Samples')
    plt.title('Dataset Distribution')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()

    logger.info(f"Visualization saved to {save_path}")

# %%
if __name__ == "__main__":
    # Initialize MediaPipe Hands
    hands = init_mp_hands()

    # Process images (with counting and sharpening integrated)
    data, labels = process_images(DATA_DIR, hands)

    # Save processed data
    save_data_pickle(data, labels)

    # Save visualization in /graphs
    visualize_data(labels)
# Out:
# 2025-09-27 10:20:47,178 | INFO     | __main__ | Initializing MediaPipe Hands...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758948647.255276   84161 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# 2025-09-27 10:20:47,255 | INFO     | __main__ | Processing images from: /Users/ashishsingh/Desktop/SIGN/data/numbers
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1758948647.263858   84323 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758948647.269172   84324 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 2025-09-27 10:20:47,406 | INFO     | __main__ | Found 35275 images to process in /Users/ashishsingh/Desktop/SIGN/data/numbers.
# 2025-09-27 10:20:47,406 | DEBUG    | __main__ | Skipping: .DS_Store
# W0000 00:00:1758948647.446600   84319 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# 2025-09-27 10:20:47,908 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/1347.jpg
# 2025-09-27 10:20:47,924 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/2896.jpg
# 2025-09-27 10:20:47,941 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/638.jpg
# 2025-09-27 10:20:48,010 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/604.jpg
# 2025-09-27 10:20:48,150 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/2855.jpg
# 2025-09-27 10:20:48,201 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/610.jpg
# 2025-09-27 10:20:48,429 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/1637.jpg
# 2025-09-27 10:20:48,472 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/2458.jpg
# 2025-09-27 10:20:48,985 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/599.jpg
# 2025-09-27 10:20:49,521 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/572.jpg
# 2025-09-27 10:20:49,538 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/566.jpg
# 2025-09-27 10:20:49,956 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/3342.jpg
# 2025-09-27 10:20:50,028 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/2909.jpg
# 2025-09-27 10:20:50,721 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/2908.jpg
# 2025-09-27 10:20:50,767 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/3343.jpg
# 2025-09-27 10:20:51,122 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/567.jpg
# 2025-09-27 10:20:51,390 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/573.jpg
# 2025-09-27 10:20:51,726 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/598.jpg
# 2025-09-27 10:20:52,306 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/1636.jpg
# 2025-09-27 10:20:52,408 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9/2471.jpg
# 2025-09-27 10:20:52,631 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/9
| DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2705.jpg
# 2025-09-27 10:36:29,580 | WARNING  | __main__ | Failed to load image: /Users/ashishsingh/Desktop/SIGN/data/numbers/5/.DS_Store
# 2025-09-27 10:36:30,321 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445012.jpg
# 2025-09-27 10:36:30,850 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2067.jpg
# 2025-09-27 10:36:35,265 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/3019.jpg
# 2025-09-27 10:36:36,330 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2298.jpg
# 2025-09-27 10:36:38,430 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2299.jpg
# 2025-09-27 10:36:39,785 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/3018.jpg
# 2025-09-27 10:36:44,283 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2943.jpg
# 2025-09-27 10:36:46,427 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/672.jpg
# 2025-09-27 10:36:47,955 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/658.jpg
# 2025-09-27 10:36:51,191 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2001.jpg
# 2025-09-27 10:36:52,516 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/665.jpg
# 2025-09-27 10:36:53,683 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2830.jpg
# 2025-09-27 10:36:55,492 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2777.jpg
# 2025-09-27 10:36:56,080 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2776.jpg
# 2025-09-27 10:36:57,533 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2831.jpg
# 2025-09-27 10:36:58,999 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/3091.jpg
# 2025-09-27 10:37:01,194 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2832.jpg
# 2025-09-27 10:37:01,211 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/677.jpg
# 2025-09-27 10:37:02,196 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445122.jpg
# 2025-09-27 10:37:03,650 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445297.jpg
# 2025-09-27 10:37:04,424 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/446013.jpg
# 2025-09-27 10:37:04,783 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2778.jpg
# 2025-09-27 10:37:04,988 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445056.jpg
# 2025-09-27 10:37:06,012 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/2779.jpg
# 2025-09-27 10:37:06,058 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445902.jpg
# 2025-09-27 10:37:06,359 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/446012.jpg
# 2025-09-27 10:37:07,039 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445296.jpg
# 2025-09-27 10:37:08,530 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445123.jpg
# 2025-09-27 10:37:09,466 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445121.jpg
# 2025-09-27 10:37:11,634 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/446010.jpg
# 2025-09-27 10:37:13,657 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/446011.jpg
# 2025-09-27 10:37:16,660 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/654.jpg
# 2025-09-27 10:37:19,743 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445045.jpg
# 2025-09-27 10:37:20,770 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/446014.jpg
# 2025-09-27 10:37:22,654 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/655.jpg
# 2025-09-27 10:37:25,600 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/446016.jpg
# 2025-09-27 10:37:26,881 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445708.jpg
# 2025-09-27 10:37:28,130 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/444990.jpg
# 2025-09-27 10:37:33,144 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445034.jpg
# 2025-09-27 10:37:35,713 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445829.jpg
# 2025-09-27 10:37:36,209 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/197.jpg
# 2025-09-27 10:37:38,841 | DEBUG    | __main__ | No hands detected in /Users/ashishsingh/Desktop/SIGN/data/numbers/5/445023.jpg
# 2025-09-27 10:37:53,638 | INFO     | __main__ | Processing complete: 35275 images total, MediaPipe detected hands in 32540 images (skipped 2745).
# 2025-09-27 10:37:53,667 | INFO     | __main__ | Processed data saved to /Users/ashishsingh/Desktop/SIGN/data/processed_data/numbers/data.pickle
# 2025-09-27 10:37:53,667 | INFO     | __main__ | Generating dataset distribution visualization...
# 2025-09-27 10:37:53,679 | DEBUG    | matplotlib.pyplot | Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2025-09-27 10:37:53,680 | DEBUG    | matplotlib.pyplot | Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2025-09-27 10:37:53,687 | INFO     | matplotlib.category | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-09-27 10:37:53,687 | INFO     | matplotlib.category | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-09-27 10:37:53,770 | INFO     | __main__ | Visualization saved to /Users/ashishsingh/Desktop/SIGN/graphs/data_visualization.png
